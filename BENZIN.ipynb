# %% [markdown]
# <a href="https://colab.research.google.com/github/wowozella/Book_Charecters_Plots/blob/main/BENZIN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **In The Name Of GOD!**

# %% [markdown]
# # BENZIN project

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Installing Jdatetime for Persian Calendar and importing it

# %%
! pip install jdatetime

# %%
import jdatetime as jd

# %% [markdown]
# Loading BENZIN.CSV

# %%
data = pd.read_csv("BENZIN.CSV")

# %% [markdown]
# Showing Data

# %%
data.head(10)
# Out:
#    Liter      Date  Distance
# 0   40.0  14030809     349.7
# 1   25.0  14030812     445.8
# 2   30.0  14030813     408.4
# 3   25.0  14030830     398.0
# 4   28.0  14030906     461.1
# 5   30.0  14030912     418.3
# 6   30.0  14030913     562.4
# 7   35.0  14030918     320.1
# 8   25.0  14031002     315.2
# 9   30.0  14031006     379.0

# %% [markdown]
# Describe Data

# %%
data.describe()
# Out:
#            Liter          Date    Distance
# count  36.000000  3.600000e+01   36.000000
# mean   24.875833  1.403488e+07  357.822222
# std     5.676047  4.645104e+03  105.492638
# min    13.000000  1.403081e+07   59.300000
# 25%    20.000000  1.403100e+07  337.700000
# 50%    25.000000  1.403117e+07  368.500000
# 75%    30.000000  1.404024e+07  419.125000
# max    40.000000  1.404041e+07  562.400000

# %% [markdown]
# Making Plot date for "X axis" and Liter and Distance for "Y Axis"

# %%
plt.show()
